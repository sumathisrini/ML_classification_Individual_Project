# %% [markdown]
# # Project -Obesity

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ObesityDataset.csv')

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %% [raw]
# Gender
# Age
# Height
# Weight
# family_history_with_overweight
# FAVC	Do you eat high caloric food frequently?
# FCVC	Do you usually eat vegetables in your meals
# NCP	    How many main meals do you have daily
# CAEC	Do you eat any food between meals?
# SMOKE	Do you smoke?
# CH2O	How much water do you drink daily?
# SCC	    Do you monitor the calories you eat daily?
# FAF	    How often do you have physical activity?
# TUE	    How much time do you use technological devices such as
#         cell phone, videogames, television, computer and others?
# CALC	how often do you drink alcohol?
# MTRANS	Which transportation do you usually use?
# NObeyesdad

# %%
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
# convert gender col  Male to 0 and female to 1
df['Gender']=df['Gender'].map({'Male':0,'Female':1}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                            yes
# 1          1  21.000000  1.520000   56.000000                            yes
# 2          0  23.000000  1.800000   77.000000                            yes
# 3          0  27.000000  1.800000   87.000000                             no
# 4          0  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106       1  20.976842  1.710730  131.408528                            yes
# 2107       1  21.982942  1.748584  133.742943                            yes
# 2108       1  22.524036  1.752206  133.689352                            yes
# 2109       1  24.361936  1.739450  133.346641                            yes
# 2110       1  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
# convert family_history_with_overweight col  no to 0 and yes to 1
df['family_history_with_overweight']=df['family_history_with_overweight'].map({'no':0,'yes':1}).astype(int)

# %%
# FAVC	Do you eat high caloric food frequently?
# convert no: 0, yes:1
df['FAVC']=df['FAVC'].map({'no':0,'yes':1}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.CAEC.unique()
# Out:
# array(['Sometimes', 'Frequently', 'Always', 'no'], dtype=object)

# %%
# CAEC Do you eat any food between meals?
#['Sometimes', 'Frequently', 'Always', 'no']
# convert no':0,'Sometimes':1,'Frequently':2,'Always':3
df['CAEC']=df['CAEC'].map({'no':0,'Sometimes':1,'Frequently':2,'Always':3}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.SCC.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# SCC	    Do you monitor the calories you eat daily?
# convert no: 0, yes:1
df['SCC']=df['SCC'].map({'no':0,'yes':1}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.SMOKE.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
SMOKE	Do you smoke?
# convert no: 0, yes:1
df['SMOKE']=df['SMOKE'].map({'no':0,'yes':1}).astype(int)
df
# Out:
# Object `smoke` not found.
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.CALC.unique()
# Out:
# array(['no', 'Sometimes', 'Frequently', 'Always'], dtype=object)

# %%
# CALC	how often do you drink alcohol?
# ['no', 'Sometimes', 'Frequently', 'Always']
df['CALC']=df['CALC'].map({'no':0,'Sometimes':1,'Frequently':2,'Always':3}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.MTRANS.unique()
# Out:
# array(['Public_Transportation', 'Walking', 'Automobile', 'Motorbike',
#        'Bike'], dtype=object)

# %%
# MTRANS	Which transportation do you usually use?
#['Public_Transportation', 'Walking', 'Automobile', 'Motorbike','Bike']
#convert 'Walking':0,'Public_Transportation':1,'Automobile':2,'Motorbike':3,'Bike':4
df['MTRANS']=df['MTRANS'].map({'Walking':0,'Public_Transportation':1,'Automobile':2,'Motorbike':3,'Bike':4}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
df.NObeyesdad.unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
# obseity 
# convert 'Normal_Weight':0,'Overweight_Level_I':1,'Overweight_Level_II':2,'Obesity_Type_I':3,'Obesity_Type_II':4,'Obesity_Type_III':5 ,'Insufficient_Weight':-1
df['NObeyesdad']=df['NObeyesdad'].map({'Normal_Weight':0,'Overweight_Level_I':1,'Overweight_Level_II':2,'Obesity_Type_I':3,'Obesity_Type_II':4,'Obesity_Type_III':5 ,'Insufficient_Weight':-1}).astype(int)
df
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          1  21.000000  1.620000   64.000000                               1
# 1          1  21.000000  1.520000   56.000000                               1
# 2          0  23.000000  1.800000   77.000000                               1
# 3          0  27.000000  1.800000   87.000000                               0
# 4          0  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2106       1  20.976842  1.710730  131.408528                               1
# 2107       1  21.982942  1.748584  133.742943                               1
# 2108       1  22.524036  1.752206  133.689352                               1
# 2109       1  24.361936  1.739450  133.346641                               1
# 2110       1  23.664709  1.738836  133.472641                               1
#
# ...

# %%
from scipy import stats
Q1 = df.Age.quantile(0.25)
Q3 = df.Age.quantile(0.75)
IQR = Q3 - Q1
#print(df.shape)

print(IQR)
# Out:
# 6.052807999999999

# %%
res_outlier=df.Age[(df.Age < (Q1 - 1.5 * IQR)) |(df.Age > (Q3 + 1.5 * IQR))]
res_outlier.isna().sum()
# Out:
# 0

# %%
from scipy import stats
Q1 = df.Height.quantile(0.25)
Q3 = df.Height.quantile(0.75)
IQR = Q3 - Q1
#print(df.shape)

print(IQR)
# Out:
# 0.13846400000000014

# %%
res_outlier=df.Height[(df.Height < (Q1 - 1.5 * IQR)) |(df.Height > (Q3 + 1.5 * IQR))]
res_outlier.isna().sum()
# Out:
# 0

# %%
from scipy import stats
Q1 = df.Weight.quantile(0.25)
Q3 = df.Weight.quantile(0.75)
IQR = Q3 - Q1
#print(df.shape)

print(IQR)
# Out:
# 41.957339000000005

# %%
res_outlier=df.Weight[(df.Weight < (Q1 - 1.5 * IQR)) |(df.Weight > (Q3 + 1.5 * IQR))]
res_outlier.isna().sum()
# Out:
# 0

# %%
# from above outliers checking we are sure that we don't have any outlier in contionous value

# %%
# finding duplicates and droping them
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.nunique()
# Out:
# Gender                               2
# Age                               1402
# Height                            1574
# Weight                            1525
# family_history_with_overweight       2
# FAVC                                 2
# FCVC                               810
# NCP                                635
# CAEC                                 4
# SMOKE                                2
# CH2O                              1268
# SCC                                  2
# FAF                               1190
# TUE                               1129
# CALC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2087 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2087 non-null   int32
#  1   Age                             2087 non-null   float64
#  2   Height                          2087 non-null   float64
#  3   Weight                          2087 non-null   float64
#  4   family_history_with_overweight  2087 non-null   int32
#  5   FAVC                            2087 non-null   int32
#  6   FCVC                            2087 non-null   float64
#  7   NCP                             2087 non-null   float64
#  8   CAEC                            2087 non-null   int32
#  9   SMOKE                           2087 non-null   int32
#  10  CH2O                            2087 non-null   float64
#  11  SCC                             2087 non-null   int32
# ...

# %%
df.describe().T
# Out:
#                                  count       mean        std    min  \
# Gender                          2087.0   0.495927   0.500103   0.00
# Age                             2087.0  24.353090   6.368801  14.00
# Height                          2087.0   1.702674   0.093186   1.45
# Weight                          2087.0  86.858730  26.190847  39.00
# family_history_with_overweight  2087.0   0.825108   0.379966   0.00
# FAVC                            2087.0   0.883565   0.320823   0.00
# FCVC                            2087.0   2.421466   0.534737   1.00
# NCP                             2087.0   2.701179   0.764614   1.00
# CAEC                            2087.0   1.146143   0.459494   0.00
# SMOKE                           2087.0   0.021083   0.143695   0.00
# CH2O                            2087.0   2.004749   0.608284   1.00
# SCC                             2087.0   0.045999   0.209533   0.00
# FAF                             2087.0   1.012812   0.853475   0.00
# ...

# %%
df.corr()
# Out:
#                                   Gender       Age    Height    Weight  \
# Gender                          1.000000 -0.050641 -0.626748 -0.163176
# Age                            -0.050641  1.000000 -0.031748  0.198160
# Height                         -0.626748 -0.031748  1.000000  0.457468
# Weight                         -0.163176  0.198160  0.457468  1.000000
# family_history_with_overweight -0.113492  0.200379  0.232258  0.492969
# FAVC                           -0.061220  0.063895  0.180694  0.274655
# FCVC                            0.271575  0.013572 -0.040363  0.216574
# NCP                            -0.077863 -0.055823  0.227806  0.092149
# CAEC                            0.074564 -0.092097 -0.058001 -0.300271
# SMOKE                          -0.045501  0.091261  0.054326  0.024369
# CH2O                           -0.095129 -0.044058  0.220487  0.203823
# SCC                             0.102435 -0.117959 -0.137078 -0.205409
# ...

# %%
import matplotlib.pyplot as plt
for feature in df.columns:
    plt.title(feature)
    plt.hist(df[feature])
    plt.show()

# %%
# Split the x /input and y /output col
x=df.iloc[:,0:16].values
y=df.iloc[:,16].values

# %%
x
# Out:
# array([[ 1.      , 21.      ,  1.62    , ...,  1.      ,  0.      ,
#          1.      ],
#        [ 1.      , 21.      ,  1.52    , ...,  0.      ,  1.      ,
#          1.      ],
#        [ 0.      , 23.      ,  1.8     , ...,  1.      ,  2.      ,
#          1.      ],
#        ...,
#        [ 1.      , 22.524036,  1.752206, ...,  0.646288,  1.      ,
#          1.      ],
#        [ 1.      , 24.361936,  1.73945 , ...,  0.586035,  1.      ,
#          1.      ],
#        [ 1.      , 23.664709,  1.738836, ...,  0.714137,  1.      ,
#          1.      ]])

# %%
y
# Out:
# array([0, 0, 0, ..., 5, 5, 5])

# %%
# Now we hv to didvide the data into train and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=0)

# %%
# scaling the data set
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
# Bring in 6 models and run the data to find which model is best fit
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
# it uses stratified logic to test the data.
from sklearn.model_selection import StratifiedKFold

# cross val score will give the score of ytest and ypredicted
from sklearn.model_selection import cross_val_score

# %%
# Add all the models to same data set are in a list.
models=[]
models.append(('LR',LogisticRegression(solver='liblinear',multi_class='ovr')))
models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DT',DecisionTreeClassifier()))
models.append(('RDF',RandomForestClassifier()))
models.append(('NB',GaussianNB()))
models.append(('SVM',SVC(gamma='auto')))

# %%
#Running the models
names=[]
res=[]
for name,model in models:
    kfold=StratifiedKFold(n_splits=10,random_state=None)
    cv_results=cross_val_score(model,x_train,y_train,cv=kfold,scoring='accuracy')
    names.append(name)
    res.append(cv_results.mean())
    print(name,cv_results.mean())
# Out:
# LR 0.7431569492079046
# LDA 0.8952474277315042
# KNN 0.797472644128695
# DT 0.9322962600032664
# RDF 0.9476073820022866
# NB 0.6013473787359137
# SVM 0.8754409603135718

# %%
# ploting all the above values
plt.ylim(.200,.999)
plt.bar(names,res,color='Green',width=0.6)
plt.title('Algorithm Comparision')
plt.show()

# %%
# from  above comparision we can say that Random forest is good one has got better accuarcy
model=RandomForestClassifier(random_state=0)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Confusion Matrix:
# [[58  2  0  0  0  0  0]
#  [ 0 62  2  1  0  0  0]
#  [ 0  5 62  2  0  0  0]
#  [ 0  4  2 68  0  0  0]
#  [ 0  0  1  1 95  1  0]
#  [ 0  0  0  0  0 80  0]
#  [ 0  0  0  0  0  0 76]]
# Accuracy of the Model: 95.97701149425288%

# %%
#  For multi class classification problem, our evalutaion metrics will have an additional parameter called micro and macro

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, y_pred, target_names=['Class 1', 'Class 2', 'Class 3','Class 4','Class 5','Class 6', 'Class 7']))
# Out:
# Accuracy: 0.96
#
# Micro Precision: 0.96
# Micro Recall: 0.96
# Micro F1-score: 0.96
#
# Macro Precision: 0.96
# Macro Recall: 0.96
# Macro F1-score: 0.96
#
# Weighted Precision: 0.96
# Weighted Recall: 0.96
# Weighted F1-score: 0.96
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.97      0.98        60
#      Class 2       0.85      0.95      0.90        65
#      Class 3       0.93      0.90      0.91        69
#      Class 4       0.94      0.92      0.93        74
#      Class 5       1.00      0.97      0.98        98
#      Class 6       0.99      1.00      0.99        80
#      Class 7       1.00      1.00      1.00        76
#
#     accuracy                           0.96       522
#    macro avg       0.96      0.96      0.96       522
# weighted avg       0.96      0.96      0.96       522

# %% [markdown]
# # PCA

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(x_train)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca= PCA(n_components =2)
pca.fit(x_train)
x_pca=pca.transform(x_train)
x_pca.shape
# Out:
# (1565, 2)

# %%
print(x_pca)
# Out:
# [[-2.31889123  0.46645673]
#  [ 1.83916336 -0.1001549 ]
#  [-0.69875297 -1.32735596]
#  ...
#  [-1.15856049  0.52120133]
#  [-0.4438973  -1.099416  ]
#  [-2.58878827  0.2912523 ]]

# %%
model=RandomForestClassifier(random_state=0)
model.fit(x_pca,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pca= PCA(n_components =2)
pca.fit(x_test)
x_testpca=pca.transform(x_test)
x_testpca.shape
y_pred=model.predict(x_testpca)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix: ")
print(cm)
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Confusion Matrix:
# [[24 21  6  4  2  2  1]
#  [12 25 10  7  5  3  3]
#  [ 5 14 17  9 16  3  5]
#  [ 7 14 15 11 10  4 13]
#  [ 3  7 17 11 40  8 12]
#  [ 0  1  1  6 12 51  9]
#  [ 0  0  1  4  7  5 59]]
# Accuracy of the Model: 43.486590038314176%

# %%
#  For multi class classification problem, our evalutaion metrics will have an additional parameter called micro and macro

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, y_pred, target_names=['Class 1', 'Class 2', 'Class 3','Class 4','Class 5','Class 6', 'Class 7']))
# Out:
# Accuracy: 0.43
#
# Micro Precision: 0.43
# Micro Recall: 0.43
# Micro F1-score: 0.43
#
# Macro Precision: 0.42
# Macro Recall: 0.43
# Macro F1-score: 0.42
#
# Weighted Precision: 0.42
# Weighted Recall: 0.43
# Weighted F1-score: 0.43
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       0.47      0.40      0.43        60
#      Class 2       0.30      0.38      0.34        65
#      Class 3       0.25      0.25      0.25        69
#      Class 4       0.21      0.15      0.17        74
#      Class 5       0.43      0.41      0.42        98
#      Class 6       0.67      0.64      0.65        80
#      Class 7       0.58      0.78      0.66        76
#
#     accuracy                           0.43       522
#    macro avg       0.42      0.43      0.42       522
# weighted avg       0.42      0.43      0.43       522
